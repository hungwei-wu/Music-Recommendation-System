# %%
import pandas as pd
# df = pd.read_csv("song_word2vec/song_word2vec_whole_part2.csv",sep=',',dtype=object)
df = pd.read_csv("song_word2vec_whole_truncate_50000_new.csv",sep=',',dtype=object)

# %%
print (df.head(1))
# Out:
#           Unnamed: 0               0              1                2  \
# 0  b'Boy, Boy, Boy '  -0.08447265625  -0.0771484375  -0.042236328125
#
#            3              4           5                  6           7  \
# 0  0.2421875  -0.1513671875  0.17578125  -0.00860595703125  0.23046875
#
#                8      ...                1490               1491  \
# 0  0.11962890625      ...       0.01904296875  -0.01031494140625
#
#            1492          1493           1494           1495         1496  \
# 0  -0.115234375  -0.291015625  -0.0595703125  -0.0537109375  -0.07421875
#
#         1497            1498          1499
# 0  -0.265625  -0.10302734375  0.1357421875
#
# [1 rows x 1501 columns]

# %%
df = df.rename(columns={ df.columns[0] : 'traname'})
df["traname"] = df["traname"].apply(lambda x: x[2:-1])
df.head(5)
# Out:
#                           traname                 0              1  \
# 0                  Boy, Boy, Boy     -0.08447265625  -0.0771484375
# 1                      Crocodile          0.1328125    0.314453125
# 2               You Already Know    -0.033935546875     0.16015625
# 3  Inutile \xc3\x89ternit\xc3\xa9         0.0390625    0.154296875
# 4                       Loveless   0.00836181640625    0.083984375
#
#                   2                   3               4              5  \
# 0   -0.042236328125           0.2421875   -0.1513671875     0.17578125
# 1  0.00946044921875          0.16796875    -0.189453125  -0.1396484375
# 2     0.12060546875        0.0673828125  -0.10986328125  0.09521484375
# 3          -0.15625  -0.006683349609375   0.06982421875  0.06494140625
# 4      0.2158203125        0.0888671875    -0.287109375    0.162109375
#
#                    6                7               8       ...         \
# ...

# %%
tra2vec_df = df.set_index("traname")
#tra2vec_df
tra2vec_df.head(10)
# Out:
#                                                 0                1  \
# traname
# Boy, Boy, Boy                      -0.08447265625    -0.0771484375
# Crocodile                               0.1328125      0.314453125
# You Already Know                  -0.033935546875       0.16015625
# Inutile \xc3\x89ternit\xc3\xa9          0.0390625      0.154296875
# Loveless                         0.00836181640625      0.083984375
# J\xc3\xb3ga                        -0.03466796875       -0.2734375
# On Your Own                          -0.142578125     0.1259765625
# Only This Moment                       0.12890625    -0.1650390625
# All In The Mind                 -0.00909423828125  -0.044189453125
# Sonnet                                -0.14453125    0.06787109375
#
#                                                2                   3  \
# traname
# Boy, Boy, Boy                    -0.042236328125           0.2421875
# Crocodile                       0.00946044921875          0.16796875
# ...

# %%
tra2vec_df.index
# Out:
# Index(['Boy, Boy, Boy ', 'Crocodile ', 'You Already Know ',
#        'Inutile \xc3\x89ternit\xc3\xa9', 'Loveless ', 'J\xc3\xb3ga',
#        'On Your Own ', 'Only This Moment ', 'All In The Mind ', 'Sonnet ',
#        ...
#        'Hurry On Now ', 'Midsummer Night Blues', 'Walk In The Sky ',
#        'I Beeped When I Should Have Bopped', 'Stardust', 'Magic Moments',
#        'Jitter Bug', 'Solstice ', 'Good Disease', 'Zitarrosa'],
#       dtype='object', name='traname', length=48954)

# %%
tra2vec_df.loc['Crocodile '].head(10)
# Out:
# 0           0.1328125
# 1         0.314453125
# 2    0.00946044921875
# 3          0.16796875
# 4        -0.189453125
# 5       -0.1396484375
# 6         0.130859375
# 7     -0.048095703125
# 8      -0.10986328125
# 9     -0.031982421875
# Name: Crocodile , dtype: object

# %%
vec = tra2vec_df.loc['Crocodile '].as_matrix()
vec.shape
# Out:
# (1500,)

# %%
import numpy as np
mat = np.array(vec,dtype=np.float32).reshape((5,300))

# %%
C = np.mean(mat,axis=0)

# %%
C.shape
# Out:
# (300,)

# %%
tra2vec_df.loc['Crocodile ']
# Out:
# 0                0.1328125
# 1              0.314453125
# 2         0.00946044921875
# 3               0.16796875
# 4             -0.189453125
# 5            -0.1396484375
# 6              0.130859375
# 7          -0.048095703125
# 8           -0.10986328125
# 9          -0.031982421875
# 10            0.1162109375
# 11           -0.2060546875
# 12           -0.1728515625
# 13            0.1279296875
# 14               -0.234375
# 15           0.08056640625
# 16            0.1357421875
# 17              0.16015625
# 18             0.251953125
# 19       -0.00909423828125
# 20           0.06982421875
# 21                  0.1875
# 22             0.314453125
# 23        -0.0257568359375
# 24           0.11962890625
# 25            0.1826171875
# 26          0.056884765625
# 27          0.016357421875
# 28             -0.16796875
# 29        -0.0255126953125
#                ...
# 1470              0.265625
# 1471         0.09912109375
# 1472        0.052001953125
# ...
